# %%
a = 2
b = 4
print('a= ',a,'b=',b, 'a+b=',a+b)
# Out:
# a=  2 b= 4 a+b= 6

# %%
print(f"a = {a} and b= {b} op a+b = {a+b}")
# Out:
# a = 2 and b= 4 op a+b = 6

# %%
oi = f'''
line 1 value of a is {a}
line 2 valueb of b is {b}
line 3 addition of a+b is {a+b}'''
print(oi)
# Out:
# line 1 value of a is 2
# line 2 valueb of b is 4
# line 3 addition of a+b is 6

# %%
a= 2
b=4
print(f"a+b={a+b}")
# Out:
# a+b=6

# %%
a = "This is a is value"
print(f"{a} type of a = {type(a)}")
# Out:
# This is ab value type of a = <class 'str'>

# %%
#List
l1 = ['a','b',2,3,5+5,False, f"a+b={a+b}"]
print(f"This is the values {l1} and type of l1 is{type(l1)}")
# Out:
# This is the values ['a', 'b', 2, 3, 10, False, 'a+b=6'] and type of l1 is<class 'list'>

# %%
# tuple
l2 = ('a','b',2,3,4+5,False,f"a+b={a+b}")

print(f"This is the values {l2} and type of l1 is{type(l2)}")
# Out:
# This is the values ('a', 'b', 2, 3, 9, False, 'a+b=6') and type of l1 is<class 'tuple'>

# %% [markdown]
# # Dict

# %%
d1 = {
    'id':1,
    'Name':'Bhavesh',
    'sal':123,
    'Name':'vinit',
    'age':10+2
}
print(f"type of {type(d1)}",d1)
# Out:
# type of <class 'dict'> {'id': 1, 'Name': 'vinit', 'sal': 123, 'age': 12}

# %% [markdown]
# # Set

# %%
t2 = {'s','4',3,4,5+5}
print(t2)
# Out:
# {3, 4, '4', 10, 's'}

# %%
bol1 = True
bool2 = False
statement = a== b
print(f"a is {a}, type of a is {type(a)}")
print(f"b is {b}, type of b is {type(b)}")
print(f"{statement}, type of statement is {type(statement)}")
# Out:
# a is 2, type of a is <class 'int'>
# b is 4, type of b is <class 'int'>
# False, type of statement is <class 'bool'>
