# %%
import pandas as pd


pop_10_19 = pd.read_csv("./databases/population-2010-2019.csv", skiprows=2)
#
#pop_20_29 = pd.read_csv("./pop_data/population-2020-2029.csv")

#pop_30_39 = pd.read_excel("./pop_data/population-2030-2040.xlsx")

# %%
pop_10_19.head()
# Out:
#    LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  2715.070   2600.535  5315.605
# 1    92.622     81.239   173.861
# 2  1966.415   1885.869  3852.284
# 3  2233.041   2239.035  4472.076
# 4     3.543      3.436     6.979

# %%
pop_10_19.describe()
# Out:
#               LocID          Time   AgeGrpStart    AgeGrpSpan       PopMale  \
# count  41795.000000  41790.000000  41790.000000  41790.000000  41790.000000
# mean     443.678789   2014.500000     50.000000      4.714286    878.600738
# std      275.319329      2.872316     30.276866      1.277768   4280.285697
# min        4.000000   2010.000000      0.000000     -1.000000      0.000000
# 25%      218.000000   2012.000000     25.000000      5.000000      8.155000
# 50%      428.000000   2014.500000     50.000000      5.000000     87.622000
# 75%      662.000000   2017.000000     75.000000      5.000000    415.094500
# max     1835.000000   2019.000000    100.000000      5.000000  67528.067000
#
#           PopFemale       PopTotal
# count  41790.000000   41790.000000
# mean     863.606296    1742.207034
# std     3978.167523    8255.483777
# min        0.000000       0.000000
# 25%       10.139500      18.934250
# 50%       99.384000     190.157500
# ...

# %%
pop_10_19['AgeGrp'].value_counts(normalize=True) * 100
# Out:
# AgeGrp
# 0-4          4.761905
# 05. Sep      4.761905
# Okt 14       4.761905
# 15-19        4.761905
# 20-24        4.761905
# 25-29        4.761905
# 30-34        4.761905
# 35-39        4.761905
# 40-44        4.761905
# 45-49        4.761905
# 50-54        4.761905
# 55-59        4.761905
# 60-64        4.761905
# 65-69        4.761905
# 70-74        4.761905
# 75-79        4.761905
# 80-84        4.761905
# 85-89        4.761905
# 90-94        4.761905
# 905. Sep9    4.761905
# 100+         4.761905
# Name: proportion, dtype: float64

# %%
pop_10_19['AgeGrp'].value_counts()
# Out:
# AgeGrp
# 0-4          1990
# 05. Sep      1990
# Okt 14       1990
# 15-19        1990
# 20-24        1990
# 25-29        1990
# 30-34        1990
# 35-39        1990
# 40-44        1990
# 45-49        1990
# 50-54        1990
# 55-59        1990
# 60-64        1990
# 65-69        1990
# 70-74        1990
# 75-79        1990
# 80-84        1990
# 85-89        1990
# 90-94        1990
# 905. Sep9    1990
# 100+         1990
# Name: count, dtype: int64

# %%
pop_10_19['AgeGrp'].unique()
# Out:
# array(['0-4', nan, '05. Sep', 'Okt 14', '15-19', '20-24', '25-29',
#        '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64',
#        '65-69', '70-74', '75-79', '80-84', '85-89', '90-94', '905. Sep9',
#        '100+'], dtype=object)

# %%
pop_10_19['AgeGrp'] = pop_10_19['AgeGrp'].replace('05. Sep', '5-9')

# %%
pop_10_19['AgeGrp'].unique()
# Out:
# array(['0-4', nan, '5-9', 'Okt 14', '15-19', '20-24', '25-29', '30-34',
#        '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69',
#        '70-74', '75-79', '80-84', '85-89', '90-94', '905. Sep9', '100+'],
#       dtype=object)

# %%
pop_10_19['AgeGrp'] = pop_10_19['AgeGrp'].replace('Okt 14', '10-14')

# %%
pop_10_19['AgeGrp'].unique()
# Out:
# array(['0-4', nan, '5-9', '10-14', '15-19', '20-24', '25-29', '30-34',
#        '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69',
#        '70-74', '75-79', '80-84', '85-89', '90-94', '905. Sep9', '100+'],
#       dtype=object)

# %%
pop_10_19['AgeGrp'] = pop_10_19['AgeGrp'].replace('905. Sep9', '95-99')

# %%
pop_10_19['AgeGrp'].unique()
# Out:
# array(['0-4', nan, '5-9', '10-14', '15-19', '20-24', '25-29', '30-34',
#        '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69',
#        '70-74', '75-79', '80-84', '85-89', '90-94', '95-99', '100+'],
#       dtype=object)

# %%
pop_10_19['AgeGrp'] = pop_10_19['AgeGrp'].replace('100+', '100-104')

# %%
pop_10_19['AgeGrp'].unique()
# Out:
# array(['0-4', nan, '5-9', '10-14', '15-19', '20-24', '25-29', '30-34',
#        '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69',
#        '70-74', '75-79', '80-84', '85-89', '90-94', '95-99', '100-104'],
#       dtype=object)

# %%
pop_10_19[pop_10_19['AgeGrp'].isna()]
# Out:
#     LocID Location  Time AgeGrp  AgeGrpStart  AgeGrpSpan  PopMale  PopFemale  \
# 39    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 40    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 41    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 42    111    China   NaN    NaN          NaN         NaN      NaN        NaN
# 43    111    China   NaN    NaN          NaN         NaN      NaN        NaN
#
#     PopTotal
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN

# %%
pop_10_19 = pop_10_19[pop_10_19['AgeGrp'].notna()]

# %%
pop_10_19['AgeGrp'].unique()
# Out:
# array(['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
#        '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74',
#        '75-79', '80-84', '85-89', '90-94', '95-99', '100-104'],
#       dtype=object)

# %%
pop_10_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41790 entries, 0 to 41794
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        41790 non-null  int64
#  1   Location     41790 non-null  object
#  2   Time         41790 non-null  float64
#  3   AgeGrp       41790 non-null  object
#  4   AgeGrpStart  41790 non-null  float64
#  5   AgeGrpSpan   41790 non-null  float64
#  6   PopMale      41790 non-null  float64
#  7   PopFemale    41790 non-null  float64
#  8   PopTotal     41790 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
pop_10_19.isna().sum()
# Out:
# LocID          0
# Location       0
# Time           0
# AgeGrp         0
# AgeGrpStart    0
# AgeGrpSpan     0
# PopMale        0
# PopFemale      0
# PopTotal       0
# dtype: int64

# %%
pop_10_19.describe()
# Out:
#               LocID          Time   AgeGrpStart    AgeGrpSpan       PopMale  \
# count  41790.000000  41790.000000  41790.000000  41790.000000  41790.000000
# mean     443.718593   2014.500000     50.000000      4.714286    878.600738
# std      275.311748      2.872316     30.276866      1.277768   4280.285697
# min        4.000000   2010.000000      0.000000     -1.000000      0.000000
# 25%      218.000000   2012.000000     25.000000      5.000000      8.155000
# 50%      428.000000   2014.500000     50.000000      5.000000     87.622000
# 75%      662.000000   2017.000000     75.000000      5.000000    415.094500
# max     1835.000000   2019.000000    100.000000      5.000000  67528.067000
#
#           PopFemale       PopTotal
# count  41790.000000   41790.000000
# mean     863.606296    1742.207034
# std     3978.167523    8255.483777
# min        0.000000       0.000000
# 25%       10.139500      18.934250
# 50%       99.384000     190.157500
# ...

# %%
pop_10_19 = pop_10_19.rename(columns={'Time': 'Year'})

# %%
pop_10_19.head()
# Out:
#    LocID             Location    Year AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0      4          Afghanistan  2010.0    0-4          0.0         5.0
# 1      8              Albania  2010.0    0-4          0.0         5.0
# 2     12              Algeria  2010.0    0-4          0.0         5.0
# 3     24               Angola  2010.0    0-4          0.0         5.0
# 4     28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  2715.070   2600.535  5315.605
# 1    92.622     81.239   173.861
# 2  1966.415   1885.869  3852.284
# 3  2233.041   2239.035  4472.076
# 4     3.543      3.436     6.979

# %%
pop_10_19['Year'] = pop_10_19['Year'].isna().sum()

# %%
pop_10_19['Year'] = pop_10_19['Year'].astype(int)

# %%
pop_10_19 = pop_10_19.drop(columns=['AgeGrpStart', 'AgeGrpSpan', 'PopTotal'])

# %%
pop_10_19.head()
# Out:
#    LocID             Location  Year AgeGrp   PopMale  PopFemale
# 0      4          Afghanistan     0    0-4  2715.070   2600.535
# 1      8              Albania     0    0-4    92.622     81.239
# 2     12              Algeria     0    0-4  1966.415   1885.869
# 3     24               Angola     0    0-4  2233.041   2239.035
# 4     28  Antigua and Barbuda     0    0-4     3.543      3.436

# %%
# %store pop_10_19
# Out:
# Stored 'pop_10_19' (DataFrame)
# C:\Users\sonal\AppData\Roaming\Python\Python310\site-packages\IPython\extensions\storemagic.py:229: UserWarning: This is now an optional IPython functionality, setting autorestore/pop_10_19 requires you to install the `pickleshare` library.
#   db[ 'autorestore/' + arg ] = obj

# %%
pop_10_19['Year'] = pop_10_19['Year'].astype(int)

# %%
pop_10_19
# Out:
#        LocID             Location  Year   AgeGrp   PopMale  PopFemale
# 0          4          Afghanistan     0      0-4  2715.070   2600.535
# 1          8              Albania     0      0-4    92.622     81.239
# 2         12              Algeria     0      0-4  1966.415   1885.869
# 3         24               Angola     0      0-4  2233.041   2239.035
# 4         28  Antigua and Barbuda     0      0-4     3.543      3.436
# ...      ...                  ...   ...      ...       ...        ...
# 41790    430              Liberia     0  100-104     0.000      0.000
# 41791    882                Samoa     0  100-104     0.000      0.000
# 41792    768                 Togo     0  100-104     0.000      0.000
# 41793    776                Tonga     0  100-104     0.000      0.000
# 41794    548              Vanuatu     0  100-104     0.000      0.000
#
# [41790 rows x 6 columns]

# %%
pop_10_19
# Out:
#        LocID             Location  Year   AgeGrp   PopMale  PopFemale
# 0          4          Afghanistan     0      0-4  2715.070   2600.535
# 1          8              Albania     0      0-4    92.622     81.239
# 2         12              Algeria     0      0-4  1966.415   1885.869
# 3         24               Angola     0      0-4  2233.041   2239.035
# 4         28  Antigua and Barbuda     0      0-4     3.543      3.436
# ...      ...                  ...   ...      ...       ...        ...
# 41790    430              Liberia     0  100-104     0.000      0.000
# 41791    882                Samoa     0  100-104     0.000      0.000
# 41792    768                 Togo     0  100-104     0.000      0.000
# 41793    776                Tonga     0  100-104     0.000      0.000
# 41794    548              Vanuatu     0  100-104     0.000      0.000
#
# [41790 rows x 6 columns]

# %%
pop_10_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41790 entries, 0 to 41794
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LocID      41790 non-null  int64
#  1   Location   41790 non-null  object
#  2   Year       41790 non-null  int64
#  3   AgeGrp     41790 non-null  object
#  4   PopMale    41790 non-null  float64
#  5   PopFemale  41790 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 2.2+ MB

# %%
import os

os.makedirs("clean_datasets", exist_ok=True)
pop_10_19.to_csv("clean_datasets/population-2010-2019.csv", index=False)
