# %% [markdown]
# ## create 10 dict
# * must have 4 combination
# * list of dict
# * dict of list
# * dict of dict
# * dict of dict of list
#
# * and do all dict method on each 10 dict

# %%
dict1 = {'name': 'Alice', 'age': 25}
dict2 = {'product_id': 'X-123', 'price': 99.99, 'in_stock': True}
dict3 = {}
dict4 = {'student': 'John', 'grades': [85, 92, 78]}
dict5 = {'playlist_name': 'Road Trip', 'track_ids': ['a1', 'b5', 'c3', 'd7']}
dict8 = {'database': {'user': 'admin', 'host': 'localhost'}, 'api': {'key': 'xyz'}}
dict9 = {
    'courses': {
        'math': [90, 95],
        'science': [88, 91, 85]
    }
}
dict10 = {
    'inventory': {
        'warehouse_A': ['item1', 'item2'],
        'warehouse_B': ['item3']
    },
    'backlog': ['item4']
}

# %%
d = dict1.copy()
print(f"original dictionary: {d}")
# Out:
# original dictionary: {'name': 'Alice', 'age': 25}

# %%
print(f"Access name: {d['name']}")
# Out:
# Access name: Alice

# %%
print(f"Before adding city name: {d}")
d['city'] = 'New York'
print(f"After changing city name: {d}")
# Out:
# Before adding city name: {'name': 'Alice', 'age': 25}
# After changing city name: {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
print(f"Before deleting age: {d}")
del d['age']
print(f"After deleting age: {d} ")
# Out:
# Before deleting age: {'name': 'Alice', 'age': 25, 'city': 'New York'}
# After deleting age: {'name': 'Alice', 'city': 'New York'}

# %%
d = dict1.copy()
print(d)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
print(f"Getting from dict 'name': {d.get('name')}")
print(f"Getting city from dict1 'city': {d.get('city', 'Not Found')}")
# Out:
# Getting from dict 'name': Alice
# Getting city from dict1 'city': Not Found

# %%
d = dict1.copy()
print(d)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
print(f"keys: {list(d.keys())}")
# Out:
# keys: ['name', 'age']

# %%
print(f"Values: {list(d.values())}")
# Out:
# Values: ['Alice', 25]

# %%
print(f"items: {list(d.items())}")
# Out:
# items: [('name', 'Alice'), ('age', 25)]

# %%
d = dict1.copy()
print(d)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
print(f"pop: {list(d.popitem())}, Now in dict is {d}")
# It return last inserted value from dict
# Out:
# pop: ['age', 25], Now in dict is {'name': 'Alice'}

# %%
print(f"Before clear {d}")
d.clear()
print(f"After clear dict is {d}")
# Out:
# Before clear {'name': 'Alice', 'age': 25}
# After clear dict is {}

# %%
d = dict1.copy()
print(d)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
d_copy = d.copy()
d_copy ["name"] = "Bhavesh"
print(f"Original: {d}")
print(f"Copy: {d_copy}")
# Out:
# Original: {'name': 'Alice', 'age': 25}
# Copy: {'name': 'Bhavesh', 'age': 25}

# %%
d = dict4.copy()
print(d)
# Out:
# {'student': 'John', 'grades': [85, 92, 78]}

# %%
print(f"Original grades: {d['grades']}")
d['grades'].append(57)
print(f"Grades After append: {d['grades']}")
# Out:
# Original grades: [85, 92, 78]
# Grades After append: [85, 92, 78, 57]

# %%
grades = d.get('grades', [])
grades.append(100)
print(f"Grades from get(): {grades}")
# Out:
# Grades from get(): [85, 92, 78, 57, 100]

# %%
d8 = dict8.copy()
print(d8)
# Out:
# {'database': {'user': 'admin', 'host': 'localhost'}, 'api': {'key': 'xyz'}}

# %%
db_host = d8['database']['host']
print(f"Database host: {db_host}")
# Out:
# Database host: localhost

# %%
d8['database']['password'] = 'secret'
print(f"After Adding password: {d8['database']}")
# Out:
# After Adding password: {'user': 'admin', 'host': 'localhost', 'password': 'secret'}
