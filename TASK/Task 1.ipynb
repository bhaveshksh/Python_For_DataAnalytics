# %% [markdown]
# ## this does not give me all markdown example

# %% [markdown]
# ## 1. Headers
# ### Header can used by (Double `#`)

# %% [markdown]
# **This is Header types**
# # I am Starting my Python journey
# ## This is Start
# ### This is
# #### This is
# ##### This is
# ###### This is

# %% [markdown]
# ## 2.Text Types

# %% [markdown]
# * **Italic**: `*text*`--> *text*
# * **Bold** : `**text**` -->**text**
# * **Strikethrough** : `~~text~~` --> ~~text~~
# * **combined** : `***bold And italic***` --> ***This is bold And Italic***

# %% [markdown]
# # 3. Lists

# %% [markdown]
# `**unordered List**`
#
# * This is item one
# * This is item two
#     * This is sub-item of two
#
# `**Ordered List**`
# 1. First number
# 2. Second number
# 3. Third number

# %% [markdown]
# # 4. Maths eq
# $$ 2+2 $$

# %% [markdown]
# # 5 Code

# %% [markdown]
# #### Python code
# ```
# a = "So I am Starting my Python journey For Data Analytics"
# print(a)
# ```

# %% [markdown]
# #### Output is
# ``So I am Starting my Python journey For Data Analytics``

# %%
a = "So I am Starting my Python journey For Data Analytics"
print(a)
# Out:
# So I am Starting my Python journey For Data Analytics

# %% [markdown]
# # 6 Tables
#
# # This is Employee Table
# | id | name | age |
# |--- |--- |--- |
# |**1** | **user1** |`23`|
# |**2** | **user2** |$$ 23 $$ |

# %% [markdown]
# ### Python feature
# * Interpreted language
# * Wast Communinity
# * Dynamically type
# * We can use object oriented langauge

# %% [markdown]
# ## 7 HyperLink

# %% [markdown]
# **blow is a way to get a job**
# * [x] study daily
# * [x] focus on study
# * [x] always study regularly 4 hrs
# * [] This is way to get a job

# %% [markdown]
# * **Link**: `[Google](https://www.google.com)` → [Google](https://www.google.com)
# * **Image**: `![Alt Text](url_to_image.jpg)`

# %% [markdown]
# ![Screenshot 2026-01-08 093649.png](<attachment:Screenshot 2026-01-08 093649.png>)

# %% [markdown]
# # 8 BlockQuote

# %% [markdown]
# > This is block Of Quote

# %% [markdown]
# # All Advanced markdown Steps and Methods with example

# %% [markdown]
# **By markup**
# <h1>Headers 1, title<h1>

# %% [markdown]
# `<br>`

# %% [markdown]
# simple, readable syntax and vast ecosystem <br>of libraries

# %% [markdown]
# [Youtube](https://youtu.be/wUSDVGivd-8?si=U8j8CLPJ9kulxwnv)

# %% [markdown]
# - [x] done
# - [ ] pending
