# %% [markdown]
# ## TASK 3:
#         str1 = 'a,b,c,d,c,b,a'
#
#         1. 2 string
#         2. 'abcdcba' == 'abcdcba'
#         3. 'abcdcba' == 'abcdcba'

# %% [markdown]
# ################################################################################################################################

# %% [markdown]
# #### All step regrading assigning variable
# * Here first i create empty variable and assigned variable name is `str`
# * and i create another variable name is `str1` and i assigned a value is in string
# * Now i assigned `str` value to `str1` means both variable value is same

# %%
str = ''
str1 = 'a,b,c,d,c,b,a'
str = str1

# %%
# first variable Output
print(str)
# Out:
# a,b,c,d,c,b,a

# %%
# Second variable Output
print(str1)
# Out:
# a,b,c,d,c,b,a

# %% [markdown]
# ## Now This part is very important
# * Now i create new valiable name is `newstr`
# * Here `str.split(",")` this part of code run and split each character by delimeter `(",")`
# * Output of this part is `['a','b','c','d','c','b','a']`
# * Now output is pass to the join method and join method merge each character and create one string like `'abcdcba'`

# %%
newstr = "".join(str.split(","))
print(newstr)
# Out:
# abcdcba

# %%
str = newstr

# %%
str
# Out:
# 'abcdcba'

# %%
newstr
# Out:
# 'abcdcba'

# %% [markdown]
# #### Now we are checking Palindrome
# * Here we are checking `str and newstr` is Palindrome or not

# %%
print(f"Is {str} == {newstr} palindrome, {str == newstr[::-1]}")
# Out:
# Is abcdcba == abcdcba palindrome, True
