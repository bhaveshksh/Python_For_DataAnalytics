# %%
import numpy as np

# %%
f = np.array([1, 2, 3, 4, 5])
print(f)
# Out:
# [1 2 3 4 5]

# %%
#np.mean(f)
print(np.mean(f))
# Out:
# np.float64(3.0)

# %%
a = list(range(1, 10))
print(f" a: {a}",type(a),len(a))

b= np.array(a)
print(f" b: {b}",type(b),b.shape)
# Out:
#  a: [1, 2, 3, 4, 5, 6, 7, 8, 9] <class 'list'> 9
#  b: [1 2 3 4 5 6 7 8 9] <class 'numpy.ndarray'> (9,)
