# %%
import pandas as pd

# %%
p_10_19 = pd.read_csv("./databases/population-2010-2019.csv", delimiter=",",skiprows = 2)
# Out:
# LocID              233
# Location       Estonia
# Time            2010.0
# AgeGrp           20-24
# AgeGrpStart       20.0
# AgeGrpSpan         5.0
# PopMale         52.056
# PopFemale       48.828
# PopTotal       100.884
# Name: 860, dtype: object

# %%
p_10_19
# Out:
#        LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0          4          Afghanistan  2010.0    0-4          0.0         5.0
# 1          8              Albania  2010.0    0-4          0.0         5.0
# 2         12              Algeria  2010.0    0-4          0.0         5.0
# 3         24               Angola  2010.0    0-4          0.0         5.0
# 4         28  Antigua and Barbuda  2010.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 41790    430              Liberia  2019.0   100+        100.0        -1.0
# 41791    882                Samoa  2019.0   100+        100.0        -1.0
# 41792    768                 Togo  2019.0   100+        100.0        -1.0
# 41793    776                Tonga  2019.0   100+        100.0        -1.0
# 41794    548              Vanuatu  2019.0   100+        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# 0      2715.070   2600.535  5315.605
# ...

# %%
print(p_10_19.loc[860])
# Out:
# LocID              233
# Location       Estonia
# Time            2010.0
# AgeGrp           20-24
# AgeGrpStart       20.0
# AgeGrpSpan         5.0
# PopMale         52.056
# PopFemale       48.828
# PopTotal       100.884
# Name: 860, dtype: object

# %%
print(p_10_19.loc[860])

# %%
# either using boolean indexing
result = p_10_19[ (p_10_19['LocID'] == 860) | (p_10_19['LocID'] == 4) ]

# …or explicitly with .loc
#result = p_10_19.loc[ p_10_19['LocID'] == 860 ]

result
# Out:
#        LocID     Location    Time   AgeGrp  AgeGrpStart  AgeGrpSpan   PopMale  \
# 0          4  Afghanistan  2010.0      0-4          0.0         5.0  2715.070
# 197      860   Uzbekistan  2010.0      0-4          0.0         5.0  1512.462
# 204        4  Afghanistan  2010.0  05. Sep          5.0         5.0  2423.963
# 396      860   Uzbekistan  2010.0  05. Sep          5.0         5.0  1305.248
# 403        4  Afghanistan  2010.0   Okt 14         10.0         5.0  2053.118
# ...      ...          ...     ...      ...          ...         ...       ...
# 40935    860   Uzbekistan  2017.0     100+        100.0        -1.0     0.137
# 40939      4  Afghanistan  2018.0     100+        100.0        -1.0     0.010
# 41083    860   Uzbekistan  2018.0     100+        100.0        -1.0     0.119
# 41087      4  Afghanistan  2019.0     100+        100.0        -1.0     0.010
# 41232    860   Uzbekistan  2019.0     100+        100.0        -1.0     0.105
#
#        PopFemale  PopTotal
# ...

# %%
p_10_19.query('LocID == 860' or 'LocID' == 4)
# Out:
#        LocID    Location    Time   AgeGrp  AgeGrpStart  AgeGrpSpan   PopMale  \
# 197      860  Uzbekistan  2010.0      0-4          0.0         5.0  1512.462
# 396      860  Uzbekistan  2010.0  05. Sep          5.0         5.0  1305.248
# 595      860  Uzbekistan  2010.0   Okt 14         10.0         5.0  1437.926
# 794      860  Uzbekistan  2010.0    15-19         15.0         5.0  1643.865
# 993      860  Uzbekistan  2010.0    20-24         20.0         5.0  1555.045
# ...      ...         ...     ...      ...          ...         ...       ...
# 40646    860  Uzbekistan  2015.0     100+        100.0        -1.0     0.188
# 40790    860  Uzbekistan  2016.0     100+        100.0        -1.0     0.160
# 40935    860  Uzbekistan  2017.0     100+        100.0        -1.0     0.137
# 41083    860  Uzbekistan  2018.0     100+        100.0        -1.0     0.119
# 41232    860  Uzbekistan  2019.0     100+        100.0        -1.0     0.105
#
#        PopFemale  PopTotal
# ...
