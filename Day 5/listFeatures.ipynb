# %%
l = [1,2,34,55,5]

# %%
print(f"l1 = {l} and data type is {type(l)}")
# Out:
# l1 = [1, 2, 34, 55, 5] and data type is <class 'list'>

# %%
l2 = 'a,b,c,d,c,b,a'
l3 = ''
l2 = l3
#l2[::-1] == l2[::-1]

# %%
l3
# Out:
# ''
