# %% [markdown]
# str1 = 'a,b,c,d,c,b,a'
#
# # 2 string
# # 'abcdcba' == 'abcdcba'
# abcdcba' == 'abcdcba'

# %%
str = ''
str1 = 'a,b,c,d,c,b,a'
str = str1

# %%
str
# Out:
# 'a,b,c,d,c,b,a'

# %%
str1
# Out:
# 'a,b,c,d,c,b,a'

# %%
newstr = "".join(str.split(","))
print(newstr)
# Out:
# abcdcba

# %%
str = newstr

# %%
str
# Out:
# 'abcdcba'

# %%
newstr
# Out:
# 'abcdcba'

# %%
print(f"str == newstr, {str == newstr}")
# Out:
# str == newstr, True
